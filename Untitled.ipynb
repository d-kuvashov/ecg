# %%
import wfdb
import time
from IPython.display import clear_output
x=0
y=1500

# %%
#Возобновить 
c = 'false'

# %%
#Приостановить график
c = 'true'

# %%
for a in range(50000):
    record = wfdb.rdrecord('mit-bih-arrhythmia-database-1.0.0/101', sampfrom=x, sampto=y)
    wfdb.plot_wfdb(record=record, title='MIT-BIH Record 100', figsize=(20,4))
    x+=50
    y+=50
    time.sleep(0.01)
    a = int(x*0.002778)
    print (' ', a, '\t\t\t',' ', a + 1, '\t\t\t',' ', a + 2, '\t\t\t', a + 3, '\t\t\t',' ', a + 4, sep='\t')
    clear_output(wait=True)
    if c == 'true': 
        break
    else:
        continue
# Out:
#  	0					 	1					 	2					3					 	4
